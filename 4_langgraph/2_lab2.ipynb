# %% [markdown]
# ### And welcome to Week 4, Day 3 - more LangGraph..

# %%
from typing import Annotated
from langgraph.graph import StateGraph, START
from langgraph.graph.message import add_messages
from dotenv import load_dotenv
from IPython.display import Image, display
import gradio as gr
from langgraph.prebuilt import ToolNode, tools_condition
import requests
import os
from langchain_openai import ChatOpenAI
from typing import TypedDict

# %%
# Our favorite first step! Crew was doing this for us, by the way.
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### First, let's go set up LangSmith!
#
# https://langsmith.com

# %% [markdown]
# ### Next, here is a useful function in LangChain community:

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper

serper = GoogleSerperAPIWrapper()
serper.run("What is the capital of France?")
# Out:
# 'Paris is the capital and largest city of France, with an estimated city population of 2.04 million in an area of 105.4 km2 (40.7 sq mi), and a metropolitan ... Paris is the capital of France, the largest country of Europe with 550 000 km2 (65 millions inhabitants). Paris has 2.234 million inhabitants end 2011. Paris is the capital and most populous city of France. Situated on the Seine River, in the north of the country, it is in the centre of the Île-de-France ... PARIS it is the capital and largest city of France. Located on the Seine in the country\'s north, it is a major cultural and political centre of ... Paris, city and capital of France, located along the Seine River, in the north-central part of the country. Paris is one of the world\'s most important and ... Do you know what city is called the \'City of Light\'? Join us for this exciting quiz where we uncover the capital of France! Its capital, largest city and main cultural and economic centre is Paris. French Republic. République française. Flag of France. Flag. Motto: "Liberté, égalité ... Think You\'re a Know- It-All? Take This General Knowledge Quiz # 1 || #generalknowledge #g#gkquiz. What is the Capital of France? 57. Dislike. Paris became capital of France because France evolved from a federation of counties to a kingdom, where the king was living a Paris. The ... France\'s capital is Paris. France has a population of 68 million. The language of France (French) is spoken by many more millions of people across the world.'

# %% [markdown]
# ### Now here is a LangChain wrapper class for converting functions into Tools

# %%
from langchain.agents import Tool

tool_search =Tool(
        name="search",
        func=serper.run,
        description="Useful for when you need more information from an online search"
    )

# %% [markdown]
# ### Now we can try out the tool the langchain way

# %%
tool_search.invoke("What is the capital of France?")
# Out:
# 'Paris is the capital and largest city of France, with an estimated city population of 2.04 million in an area of 105.4 km2 (40.7 sq mi), and a metropolitan ... Paris is the capital of France, the largest country of Europe with 550 000 km2 (65 millions inhabitants). Paris has 2.234 million inhabitants end 2011. Paris is the capital and most populous city of France. Situated on the Seine River, in the north of the country, it is in the centre of the Île-de-France ... France, country of northwestern Europe. Historically and culturally among the most important nations in the Western world. Think You\'re a Know- It-All? Take This General Knowledge Quiz # 1 || #generalknowledge #g#gkquiz. What is the Capital of France? 57. Dislike. PARIS it is the capital and largest city of France. Located on the Seine in the country\'s north, it is a major cultural and political centre of ... Its capital, largest city and main cultural and economic centre is Paris. French Republic. République française. Flag of France. Flag. Motto: "Liberté, égalité ... Paris became capital of France because France evolved from a federation of counties to a kingdom, where the king was living a Paris. The ... Do you know what city is called the \'City of Light\'? Join us for this exciting quiz where we uncover the capital of France! Paris, city and capital of France, located along the Seine River, in the north-central part of the country. Paris is one of the world\'s most important and ...'

# %% [markdown]
# ### And now let's write a tool ourselves
#
# We'll pick a familiar one

# %%
pushover_token = os.getenv("PUSHOVER_TOKEN")
pushover_user = os.getenv("PUSHOVER_USER")
pushover_url = "https://api.pushover.net/1/messages.json"

def push(text: str):
    """Send a push notification to the user"""
    requests.post(pushover_url, data = {"token": pushover_token, "user": pushover_user, "message": text})

# %%
tool_push = Tool(
        name="send_push_notification",
        func=push,
        description="useful for when you want to send a push notification"
    )

tool_push.invoke("Hello, me")

# %% [markdown]
# ### Back to the Graph from yesterday
#
# One small change - using TypedDict instead of BaseModel for the State object
#
# When we implement tools, we always need to make 2 changes to the code:
#
# 1. Changes to provide the tools to OpenAI in json when we make the call
#
# 2. Changes to handle the results back: look for the model staying that the finish_reason=="tool_calls" and then retrieve the call, run the function, provide the results.

# %% [markdown]
# ### Bring them together

# %%
tools = [tool_search, tool_push]

# %%
# Step 1: Define the State object
class State(TypedDict):
    messages: Annotated[list, add_messages]

# %%
# Step 2: Start the Graph Builder with this State class
graph_builder = StateGraph(State)

# %%
# This is different:

llm = ChatOpenAI(model="gpt-4o-mini")
llm_with_tools = llm.bind_tools(tools)

# %%
# Step 3: Create a Node


def chatbot(state: State):
    return {"messages": [llm_with_tools.invoke(state["messages"])]}

graph_builder.add_node("chatbot", chatbot)
graph_builder.add_node("tools", ToolNode(tools=tools))

# %%
# Step 4: Create Edges


graph_builder.add_conditional_edges( "chatbot", tools_condition, "tools")

# Any time a tool is called, we return to the chatbot to decide the next step
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START, "chatbot")

# %%
# Step 5: Compile the Graph
graph = graph_builder.compile()
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### That's it! And, let's do this:

# %%
def chat(user_input: str, history):
    result = graph.invoke({"messages": [{"role": "user", "content": user_input}]})
    return result["messages"][-1].content


gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## OK it's time to add Memory!
#
# ### BUT WAIT!
#
# We have this whole Graph maintaining the state and appending to the state.
#
# Why isn't this handling memory?
#
# ### This is a crucial point for understanding LangGraph
#
# > A super-step can be considered a single iteration over the graph nodes. Nodes that run in parallel are part of the same super-step, while nodes that run sequentially belong to separate super-steps.
#
#
# One "Super-Step" of the graph represents one invocation of passing messages between agents.
#
# In idomatic LangGraph, you call invoke to run your graph for each super-step; for each interaction.
#
# The reducer handles state updates automatically within one super-step, but not between them.
#
# That is what checkpointing achieves.

# %%
from langgraph.checkpoint.memory import MemorySaver

memory = MemorySaver()

# %%
# Steps 1 and 2
graph_builder = StateGraph(State)


# Step 3
llm = ChatOpenAI(model="gpt-4o-mini")
llm_with_tools = llm.bind_tools(tools)

def chatbot(state: State):
    print(state)
    return {"messages": [llm_with_tools.invoke(state["messages"])]}

graph_builder.add_node("chatbot", chatbot)
graph_builder.add_node("tools", ToolNode(tools=tools))

# Step 4
graph_builder.add_conditional_edges( "chatbot", tools_condition, "tools")
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START, "chatbot")

# Step 5
graph = graph_builder.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
config = {"configurable": {"thread_id": "1"}}

def chat(user_input: str, history):
    result = graph.invoke({"messages": [{"role": "user", "content": user_input}]}, config=config)
    return result["messages"][-1].content


gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# {'messages': [HumanMessage(content='who is the captain of Mumbai Indians ', additional_kwargs={}, response_metadata={}, id='2bd1dddd-ca69-4189-be73-abfabd0e98b7')]}
# {'messages': [HumanMessage(content='who is the captain of Mumbai Indians ', additional_kwargs={}, response_metadata={}, id='2bd1dddd-ca69-4189-be73-abfabd0e98b7'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_Jnwyarsw47sogXfVjxDZMqrF', 'function': {'arguments': '{"__arg1":"current captain of Mumbai Indians"}', 'name': 'search'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 96, 'total_tokens': 115, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f8f4a36a85', 'id': 'chatcmpl-DNxUoXyDqVx7ZvmCqgEgnS2skg0dR', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--83f4ade7-f454-4a05-a8d1-28de8b6de8cc-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'current captain of Mumbai Indians'}, 'id': 'call_Jnwyarsw47sogXfVjxDZMqrF', 'type': 'tool_call'}], usage_metadata={'input_tokens': 96, 'output_tokens': 19, 'total_tokens': 115, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content="The Mumbai Indians are currently captained by Hardik Pandya. ... Mahela Jayawardene was appointed as head coach of the Mumbai Indians before the 2025 season. Know the full IPL 2023 squad of Mumbai Indians, including batters, bowlers and all-rounders. The MI players will play during the Indian Premier League. Mumbai Indians ; Captain · Hardik Pandya ; Coach · Mahela Jayawardene ; Owner · Indiawin Sports Pvt. Ltd ; Venue · Wankhede Stadium. After Rohit Sharma's decade-long captaincy brought five IPL titles, Hardik Pandya took over the MI captain role in 2024 and continues to lead ... Pandya is the present captain of MI while Suryakumar has never ... Rohit Sharma was appointed Mumbai Indians' captain during IPL 2013. Missing: current | Show results with:current. Hardik Pandya appointed as the captain of Mumbai Indians for IPL 2024. ⭐ #Cricket #MumbaiIndians #HardikPandya End of an Era of Rohit Sharma's ... Missing: current | Show results with:current. List of Captains for Mumbai Indians in T20s ; RT Ponting, 2013-2013, 6 ; RG Sharma, 2013-2023, 163 ; KA Pollard, 2014-2021, 9 ; SA Yadav, 2023-2025, 2 ... The official website of five-time IPL and two-time CLT20 champions, Mumbai Indians (MI). Get all MI match updates, news, live scores, merchandise, schedule, ... Mumbai Indians are currently captained by the retired Australian player Ricky Ponting and coached by John Wright. They won the 2011 Champions League Twenty20 ... Breaking News: Not Hardik Pandya, but Suryakumar Yadav is the new captain of Mumbai Indians? IPL ... · Comments. Missing: current | Show results with:current.", name='search', id='b590405e-8032-4936-aa27-252ca75c4e8c', tool_call_id='call_Jnwyarsw47sogXfVjxDZMqrF')]}
# {'messages': [HumanMessage(content='who is the captain of Mumbai Indians ', additional_kwargs={}, response_metadata={}, id='2bd1dddd-ca69-4189-be73-abfabd0e98b7'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_Jnwyarsw47sogXfVjxDZMqrF', 'function': {'arguments': '{"__arg1":"current captain of Mumbai Indians"}', 'name': 'search'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 96, 'total_tokens': 115, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f8f4a36a85', 'id': 'chatcmpl-DNxUoXyDqVx7ZvmCqgEgnS2skg0dR', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--83f4ade7-f454-4a05-a8d1-28de8b6de8cc-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'current captain of Mumbai Indians'}, 'id': 'call_Jnwyarsw47sogXfVjxDZMqrF', 'type': 'tool_call'}], usage_metadata={'input_tokens': 96, 'output_tokens': 19, 'total_tokens': 115, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content="The Mumbai Indians are currently captained by Hardik Pandya. ... Mahela Jayawardene was appointed as head coach of the Mumbai Indians before the 2025 season. Know the full IPL 2023 squad of Mumbai Indians, including batters, bowlers and all-rounders. The MI players will play during the Indian Premier League. Mumbai Indians ; Captain · Hardik Pandya ; Coach · Mahela Jayawardene ; Owner · Indiawin Sports Pvt. Ltd ; Venue · Wankhede Stadium. After Rohit Sharma's decade-long captaincy brought five IPL titles, Hardik Pandya took over the MI captain role in 2024 and continues to lead ... Pandya is the present captain of MI while Suryakumar has never ... Rohit Sharma was appointed Mumbai Indians' captain during IPL 2013. Missing: current | Show results with:current. Hardik Pandya appointed as the captain of Mumbai Indians for IPL 2024. ⭐ #Cricket #MumbaiIndians #HardikPandya End of an Era of Rohit Sharma's ... Missing: current | Show results with:current. List of Captains for Mumbai Indians in T20s ; RT Ponting, 2013-2013, 6 ; RG Sharma, 2013-2023, 163 ; KA Pollard, 2014-2021, 9 ; SA Yadav, 2023-2025, 2 ... The official website of five-time IPL and two-time CLT20 champions, Mumbai Indians (MI). Get all MI match updates, news, live scores, merchandise, schedule, ... Mumbai Indians are currently captained by the retired Australian player Ricky Ponting and coached by John Wright. They won the 2011 Champions League Twenty20 ... Breaking News: Not Hardik Pandya, but Suryakumar Yadav is the new captain of Mumbai Indians? IPL ... · Comments. Missing: current | Show results with:current.", name='search', id='b590405e-8032-4936-aa27-252ca75c4e8c', tool_call_id='call_Jnwyarsw47sogXfVjxDZMqrF'), AIMessage(content="The current captain of the Mumbai Indians is Hardik Pandya. He took over the captaincy role in 2024 after Rohit Sharma's decade-long leadership.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 34, 'prompt_tokens': 522, 'total_tokens': 556, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f8f4a36a85', 'id': 'chatcmpl-DNxUrrhIPbQ6kjDg30aXoZUiHvCNv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--6463fc69-2a75-4804-841d-6f529e1d5d9d-0', usage_metadata={'input_tokens': 522, 'output_tokens': 34, 'total_tokens': 556, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='what w ...
# {'messages': [HumanMessage(content='who is the captain of Mumbai Indians ', additional_kwargs={}, response_metadata={}, id='2bd1dddd-ca69-4189-be73-abfabd0e98b7'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_Jnwyarsw47sogXfVjxDZMqrF', 'function': {'arguments': '{"__arg1":"current captain of Mumbai Indians"}', 'name': 'search'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 96, 'total_tokens': 115, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f8f4a36a85', 'id': 'chatcmpl-DNxUoXyDqVx7ZvmCqgEgnS2skg0dR', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--83f4ade7-f454-4a05-a8d1-28de8b6de8cc-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'current captain of Mumbai Indians'}, 'id': 'call_Jnwyarsw47sogXfVjxDZMqrF', 'type': 'tool_call'}], usage_metadata={'input_tokens': 96, 'output_tokens': 19, 'total_tokens': 115, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content="The Mumbai Indians are currently captained by Hardik Pandya. ... Mahela Jayawardene was appointed as head coach of the Mumbai Indians before the 2025 season. Know the full IPL 2023 squad of Mumbai Indians, including batters, bowlers and all-rounders. The MI players will play during the Indian Premier League. Mumbai Indians ; Captain · Hardik Pandya ; Coach · Mahela Jayawardene ; Owner · Indiawin Sports Pvt. Ltd ; Venue · Wankhede Stadium. After Rohit Sharma's decade-long captaincy brought five IPL titles, Hardik Pandya took over the MI captain role in 2024 and continues to lead ... Pandya is the present captain of MI while Suryakumar has never ... Rohit Sharma was appointed Mumbai Indians' captain during IPL 2013. Missing: current | Show results with:current. Hardik Pandya appointed as the captain of Mumbai Indians for IPL 2024. ⭐ #Cricket #MumbaiIndians #HardikPandya End of an Era of Rohit Sharma's ... Missing: current | Show results with:current. List of Captains for Mumbai Indians in T20s ; RT Ponting, 2013-2013, 6 ; RG Sharma, 2013-2023, 163 ; KA Pollard, 2014-2021, 9 ; SA Yadav, 2023-2025, 2 ... The official website of five-time IPL and two-time CLT20 champions, Mumbai Indians (MI). Get all MI match updates, news, live scores, merchandise, schedule, ... Mumbai Indians are currently captained by the retired Australian player Ricky Ponting and coached by John Wright. They won the 2011 Champions League Twenty20 ... Breaking News: Not Hardik Pandya, but Suryakumar Yadav is the new captain of Mumbai Indians? IPL ... · Comments. Missing: current | Show results with:current.", name='search', id='b590405e-8032-4936-aa27-252ca75c4e8c', tool_call_id='call_Jnwyarsw47sogXfVjxDZMqrF'), AIMessage(content="The current captain of the Mumbai Indians is Hardik Pandya. He took over the captaincy role in 2024 after Rohit Sharma's decade-long leadership.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 34, 'prompt_tokens': 522, 'total_tokens': 556, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f8f4a36a85', 'id': 'chatcmpl-DNxUrrhIPbQ6kjDg30aXoZUiHvCNv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--6463fc69-2a75-4804-841d-6f529e1d5d9d-0', usage_metadata={'input_tokens': 522, 'output_tokens': 34, 'total_tokens': 556, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='what w ...
# {'messages': [HumanMessage(content='who is the captain of Mumbai Indians ', additional_kwargs={}, response_metadata={}, id='2bd1dddd-ca69-4189-be73-abfabd0e98b7'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_Jnwyarsw47sogXfVjxDZMqrF', 'function': {'arguments': '{"__arg1":"current captain of Mumbai Indians"}', 'name': 'search'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 96, 'total_tokens': 115, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f8f4a36a85', 'id': 'chatcmpl-DNxUoXyDqVx7ZvmCqgEgnS2skg0dR', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--83f4ade7-f454-4a05-a8d1-28de8b6de8cc-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'current captain of Mumbai Indians'}, 'id': 'call_Jnwyarsw47sogXfVjxDZMqrF', 'type': 'tool_call'}], usage_metadata={'input_tokens': 96, 'output_tokens': 19, 'total_tokens': 115, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content="The Mumbai Indians are currently captained by Hardik Pandya. ... Mahela Jayawardene was appointed as head coach of the Mumbai Indians before the 2025 season. Know the full IPL 2023 squad of Mumbai Indians, including batters, bowlers and all-rounders. The MI players will play during the Indian Premier League. Mumbai Indians ; Captain · Hardik Pandya ; Coach · Mahela Jayawardene ; Owner · Indiawin Sports Pvt. Ltd ; Venue · Wankhede Stadium. After Rohit Sharma's decade-long captaincy brought five IPL titles, Hardik Pandya took over the MI captain role in 2024 and continues to lead ... Pandya is the present captain of MI while Suryakumar has never ... Rohit Sharma was appointed Mumbai Indians' captain during IPL 2013. Missing: current | Show results with:current. Hardik Pandya appointed as the captain of Mumbai Indians for IPL 2024. ⭐ #Cricket #MumbaiIndians #HardikPandya End of an Era of Rohit Sharma's ... Missing: current | Show results with:current. List of Captains for Mumbai Indians in T20s ; RT Ponting, 2013-2013, 6 ; RG Sharma, 2013-2023, 163 ; KA Pollard, 2014-2021, 9 ; SA Yadav, 2023-2025, 2 ... The official website of five-time IPL and two-time CLT20 champions, Mumbai Indians (MI). Get all MI match updates, news, live scores, merchandise, schedule, ... Mumbai Indians are currently captained by the retired Australian player Ricky Ponting and coached by John Wright. They won the 2011 Champions League Twenty20 ... Breaking News: Not Hardik Pandya, but Suryakumar Yadav is the new captain of Mumbai Indians? IPL ... · Comments. Missing: current | Show results with:current.", name='search', id='b590405e-8032-4936-aa27-252ca75c4e8c', tool_call_id='call_Jnwyarsw47sogXfVjxDZMqrF'), AIMessage(content="The current captain of the Mumbai Indians is Hardik Pandya. He took over the captaincy role in 2024 after Rohit Sharma's decade-long leadership.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 34, 'prompt_tokens': 522, 'total_tokens': 556, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f8f4a36a85', 'id': 'chatcmpl-DNxUrrhIPbQ6kjDg30aXoZUiHvCNv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--6463fc69-2a75-4804-841d-6f529e1d5d9d-0', usage_metadata={'input_tokens': 522, 'output_tokens': 34, 'total_tokens': 556, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='what w ...
# {'messages': [HumanMessage(content='who is the captain of Mumbai Indians ', additional_kwargs={}, response_metadata={}, id='2bd1dddd-ca69-4189-be73-abfabd0e98b7'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_Jnwyarsw47sogXfVjxDZMqrF', 'function': {'arguments': '{"__arg1":"current captain of Mumbai Indians"}', 'name': 'search'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 96, 'total_tokens': 115, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f8f4a36a85', 'id': 'chatcmpl-DNxUoXyDqVx7ZvmCqgEgnS2skg0dR', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--83f4ade7-f454-4a05-a8d1-28de8b6de8cc-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'current captain of Mumbai Indians'}, 'id': 'call_Jnwyarsw47sogXfVjxDZMqrF', 'type': 'tool_call'}], usage_metadata={'input_tokens': 96, 'output_tokens': 19, 'total_tokens': 115, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content="The Mumbai Indians are currently captained by Hardik Pandya. ... Mahela Jayawardene was appointed as head coach of the Mumbai Indians before the 2025 season. Know the full IPL 2023 squad of Mumbai Indians, including batters, bowlers and all-rounders. The MI players will play during the Indian Premier League. Mumbai Indians ; Captain · Hardik Pandya ; Coach · Mahela Jayawardene ; Owner · Indiawin Sports Pvt. Ltd ; Venue · Wankhede Stadium. After Rohit Sharma's decade-long captaincy brought five IPL titles, Hardik Pandya took over the MI captain role in 2024 and continues to lead ... Pandya is the present captain of MI while Suryakumar has never ... Rohit Sharma was appointed Mumbai Indians' captain during IPL 2013. Missing: current | Show results with:current. Hardik Pandya appointed as the captain of Mumbai Indians for IPL 2024. ⭐ #Cricket #MumbaiIndians #HardikPandya End of an Era of Rohit Sharma's ... Missing: current | Show results with:current. List of Captains for Mumbai Indians in T20s ; RT Ponting, 2013-2013, 6 ; RG Sharma, 2013-2023, 163 ; KA Pollard, 2014-2021, 9 ; SA Yadav, 2023-2025, 2 ... The official website of five-time IPL and two-time CLT20 champions, Mumbai Indians (MI). Get all MI match updates, news, live scores, merchandise, schedule, ... Mumbai Indians are currently captained by the retired Australian player Ricky Ponting and coached by John Wright. They won the 2011 Champions League Twenty20 ... Breaking News: Not Hardik Pandya, but Suryakumar Yadav is the new captain of Mumbai Indians? IPL ... · Comments. Missing: current | Show results with:current.", name='search', id='b590405e-8032-4936-aa27-252ca75c4e8c', tool_call_id='call_Jnwyarsw47sogXfVjxDZMqrF'), AIMessage(content="The current captain of the Mumbai Indians is Hardik Pandya. He took over the captaincy role in 2024 after Rohit Sharma's decade-long leadership.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 34, 'prompt_tokens': 522, 'total_tokens': 556, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f8f4a36a85', 'id': 'chatcmpl-DNxUrrhIPbQ6kjDg30aXoZUiHvCNv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--6463fc69-2a75-4804-841d-6f529e1d5d9d-0', usage_metadata={'input_tokens': 522, 'output_tokens': 34, 'total_tokens': 556, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='what w ...

# %%
graph.get_state(config)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='what is the capital of Pakistan?', additional_kwargs={}, response_metadata={}, id='22cefe5a-3a8e-4e0c-8dec-ec0c5111d944'), AIMessage(content='The capital of Pakistan is Islamabad.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 95, 'total_tokens': 103, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a1681c17ec', 'id': 'chatcmpl-DJZmAJe7C1q8jQUixGNfNC1oEEetD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--ae978d0a-30f2-4c8a-9bfc-93e0d15a3d19-0', usage_metadata={'input_tokens': 95, 'output_tokens': 8, 'total_tokens': 103, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Who is the prime minister?', additional_kwargs={}, response_metadata={}, id='a4e2606e-8140-4023-bb74-835454ff8967'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_0EAUp7sdGSZOMRtiyiZfyxwx', 'function': {'arguments': '{"__arg1":"current Prime Minister of Pakistan 2023"}', 'name': 'search'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 116, 'total_tokens': 138, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a1681c17ec', 'id': 'chatcmpl-DJZmNNsBI1qP9ctba2KLI60XYzdlj', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--91c2d56a-8787-496b-a127-48f80011a56a-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'current Prime Minister of Pakistan 2023'}, 'id': 'call_0EAUp7sdGSZOMRtiyiZfyxwx', 'type': 'tool_call'}], usage_metadata={'input_tokens': 116, 'output_tokens': 22, 'total_tokens': 138, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content="Mian Muhammad Shehbaz Sharif (born 23 September 1951) is a Pakistani politician and businessman who has served as the prime minister of Pakistan since March ... Prime Minister of Pakistan ; Prime ministerial standard. Incumbent Shehbaz Sharif. since 4 March 2024. Executive branch of the. Government of Pakistan ; Prime ... He was nominated as Prime Minister of Pakistan on April 11, 2022 till 9th August 2023 as joint candidate of PDM. Missing: current | Show results with:current. 30, Mr. Imran Khan, 18-08-2018 To 10-04-2022, Slowing Dow ; 31, Mian Muhammad Shehbaz Sharif, 11-04-2022 To 14-08-2023, Slowing Dow. Prime Minister of Pakistan. Mian Muhammad Shehbaz Sharif. Prime Minister of the Islamic Republic of Pakistan and President of the Pakistan Muslim League (N). Prime Minister Muhammad Shahbaz Sharif took oath of the office on 4 March 2024. Previously, he served as the Prime Minister of Pakistan from April - 2022 to ... Missing: current | Show results with:current. Mian Muhammad Shehbaz Sharif is a Pakistani politician and businessman who is currently serving as the 24th prime minister of Pakistan since March 2024, ... Shehbaz Sharif elected as Pakistan's new prime minister. Sharif elected prime minister by parliament following the removal of Imran Khan in a no ... Missing: current | Show results with:current. list of prime ministers of Pakistan ; Anwaar-ul-Haq Kakar (caretaker), Independent (Balochistan Awami Party), August 14, 2023–March 4, 2024 ; 24 ... Mr. Muhammad Shehbaz Sharif, Prime Minister of the Islamic Republic of Pakistan and President of the Pakistan Muslim League (N)", name='search', id='f2a0e57c-8ef0-4173-9f74-6cb9c191e0f0', tool_ca ...

# %%
# Most recent first

list(graph.get_state_history(config))
# Out:
# [StateSnapshot(values={'messages': [HumanMessage(content='what is the capital of Pakistan?', additional_kwargs={}, response_metadata={}, id='22cefe5a-3a8e-4e0c-8dec-ec0c5111d944'), AIMessage(content='The capital of Pakistan is Islamabad.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 95, 'total_tokens': 103, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a1681c17ec', 'id': 'chatcmpl-DJZmAJe7C1q8jQUixGNfNC1oEEetD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--ae978d0a-30f2-4c8a-9bfc-93e0d15a3d19-0', usage_metadata={'input_tokens': 95, 'output_tokens': 8, 'total_tokens': 103, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Who is the prime minister?', additional_kwargs={}, response_metadata={}, id='a4e2606e-8140-4023-bb74-835454ff8967'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_0EAUp7sdGSZOMRtiyiZfyxwx', 'function': {'arguments': '{"__arg1":"current Prime Minister of Pakistan 2023"}', 'name': 'search'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 116, 'total_tokens': 138, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a1681c17ec', 'id': 'chatcmpl-DJZmNNsBI1qP9ctba2KLI60XYzdlj', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--91c2d56a-8787-496b-a127-48f80011a56a-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'current Prime Minister of Pakistan 2023'}, 'id': 'call_0EAUp7sdGSZOMRtiyiZfyxwx', 'type': 'tool_call'}], usage_metadata={'input_tokens': 116, 'output_tokens': 22, 'total_tokens': 138, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content="Mian Muhammad Shehbaz Sharif (born 23 September 1951) is a Pakistani politician and businessman who has served as the prime minister of Pakistan since March ... Prime Minister of Pakistan ; Prime ministerial standard. Incumbent Shehbaz Sharif. since 4 March 2024. Executive branch of the. Government of Pakistan ; Prime ... He was nominated as Prime Minister of Pakistan on April 11, 2022 till 9th August 2023 as joint candidate of PDM. Missing: current | Show results with:current. 30, Mr. Imran Khan, 18-08-2018 To 10-04-2022, Slowing Dow ; 31, Mian Muhammad Shehbaz Sharif, 11-04-2022 To 14-08-2023, Slowing Dow. Prime Minister of Pakistan. Mian Muhammad Shehbaz Sharif. Prime Minister of the Islamic Republic of Pakistan and President of the Pakistan Muslim League (N). Prime Minister Muhammad Shahbaz Sharif took oath of the office on 4 March 2024. Previously, he served as the Prime Minister of Pakistan from April - 2022 to ... Missing: current | Show results with:current. Mian Muhammad Shehbaz Sharif is a Pakistani politician and businessman who is currently serving as the 24th prime minister of Pakistan since March 2024, ... Shehbaz Sharif elected as Pakistan's new prime minister. Sharif elected prime minister by parliament following the removal of Imran Khan in a no ... Missing: current | Show results with:current. list of prime ministers of Pakistan ; Anwaar-ul-Haq Kakar (caretaker), Independent (Balochistan Awami Party), August 14, 2023–March 4, 2024 ; 24 ... Mr. Muhammad Shehbaz Sharif, Prime Minister of the Islamic Republic of Pakistan and President of the Pakistan Muslim League (N)", name='search', id='f2a0e57c-8ef0-4173-9f74-6cb9c191e0f0', tool_c ...
#  StateSnapshot(values={'messages': [HumanMessage(content='what is the capital of Pakistan?', additional_kwargs={}, response_metadata={}, id='22cefe5a-3a8e-4e0c-8dec-ec0c5111d944'), AIMessage(content='The capital of Pakistan is Islamabad.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 95, 'total_tokens': 103, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a1681c17ec', 'id': 'chatcmpl-DJZmAJe7C1q8jQUixGNfNC1oEEetD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--ae978d0a-30f2-4c8a-9bfc-93e0d15a3d19-0', usage_metadata={'input_tokens': 95, 'output_tokens': 8, 'total_tokens': 103, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Who is the prime minister?', additional_kwargs={}, response_metadata={}, id='a4e2606e-8140-4023-bb74-835454ff8967'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_0EAUp7sdGSZOMRtiyiZfyxwx', 'function': {'arguments': '{"__arg1":"current Prime Minister of Pakistan 2023"}', 'name': 'search'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 116, 'total_tokens': 138, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a1681c17ec', 'id': 'chatcmpl-DJZmNNsBI1qP9ctba2KLI60XYzdlj', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--91c2d56a-8787-496b-a127-48f80011a56a-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'current Prime Minister of Pakistan 2023'}, 'id': 'call_0EAUp7sdGSZOMRtiyiZfyxwx', 'type': 'tool_call'}], usage_metadata={'input_tokens': 116, 'output_tokens': 22, 'total_tokens': 138, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content="Mian Muhammad Shehbaz Sharif (born 23 September 1951) is a Pakistani politician and businessman who has served as the prime minister of Pakistan since March ... Prime Minister of Pakistan ; Prime ministerial standard. Incumbent Shehbaz Sharif. since 4 March 2024. Executive branch of the. Government of Pakistan ; Prime ... He was nominated as Prime Minister of Pakistan on April 11, 2022 till 9th August 2023 as joint candidate of PDM. Missing: current | Show results with:current. 30, Mr. Imran Khan, 18-08-2018 To 10-04-2022, Slowing Dow ; 31, Mian Muhammad Shehbaz Sharif, 11-04-2022 To 14-08-2023, Slowing Dow. Prime Minister of Pakistan. Mian Muhammad Shehbaz Sharif. Prime Minister of the Islamic Republic of Pakistan and President of the Pakistan Muslim League (N). Prime Minister Muhammad Shahbaz Sharif took oath of the office on 4 March 2024. Previously, he served as the Prime Minister of Pakistan from April - 2022 to ... Missing: current | Show results with:current. Mian Muhammad Shehbaz Sharif is a Pakistani politician and businessman who is currently serving as the 24th prime minister of Pakistan since March 2024, ... Shehbaz Sharif elected as Pakistan's new prime minister. Sharif elected prime minister by parliament following the removal of Imran Khan in a no ... Missing: current | Show results with:current. list of prime ministers of Pakistan ; Anwaar-ul-Haq Kakar (caretaker), Independent (Balochistan Awami Party), August 14, 2023–March 4, 2024 ; 24 ... Mr. Muhammad Shehbaz Sharif, Prime Minister of the Islamic Republic of Pakistan and President of the Pakistan Muslim League (N)", name='search', id='f2a0e57c-8ef0-4173-9f74-6cb9c191e0f0', tool_c ...
#  StateSnapshot(values={'messages': [HumanMessage(content='what is the capital of Pakistan?', additional_kwargs={}, response_metadata={}, id='22cefe5a-3a8e-4e0c-8dec-ec0c5111d944'), AIMessage(content='The capital of Pakistan is Islamabad.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 95, 'total_tokens': 103, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a1681c17ec', 'id': 'chatcmpl-DJZmAJe7C1q8jQUixGNfNC1oEEetD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--ae978d0a-30f2-4c8a-9bfc-93e0d15a3d19-0', usage_metadata={'input_tokens': 95, 'output_tokens': 8, 'total_tokens': 103, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Who is the prime minister?', additional_kwargs={}, response_metadata={}, id='a4e2606e-8140-4023-bb74-835454ff8967'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_0EAUp7sdGSZOMRtiyiZfyxwx', 'function': {'arguments': '{"__arg1":"current Prime Minister of Pakistan 2023"}', 'name': 'search'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 116, 'total_tokens': 138, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a1681c17ec', 'id': 'chatcmpl-DJZmNNsBI1qP9ctba2KLI60XYzdlj', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--91c2d56a-8787-496b-a127-48f80011a56a-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'current Prime Minister of Pakistan 2023'}, 'id': 'call_0EAUp7sdGSZOMRtiyiZfyxwx', 'type': 'tool_call'}], usage_metadata={'input_tokens': 116, 'output_tokens': 22, 'total_tokens': 138, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('tools',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1203ce-8290-6bf4-8004-a32b8a9cf953'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-03-15T07:02:19.032677+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1203ce-71da-697c-8003-6b9f4639fbaa'}}, tasks=(PregelTask(id='0d54c369-e2db-abdf-73b5-261a55725a54', name='tools', path=('__pregel_pull', 'tools'), error=None, interrupts=(), state=None, result={'messages': [ToolMessage(content="Mian Muhammad Shehbaz Sharif (born 23 September 1951) is a Pakistani politician and businessman who has served as the prime minister of Pakistan since March ... Prime Minister of Pakistan ; Prime ministerial standard. Incumbent Shehbaz Sharif. since 4 March 2024. Executive branch of the. Government of Pakistan ; Prime ... He was nominated as Prime Minister of Pakistan on April 11, 2022 till 9th August 2023 as joint candidate of PDM. Missing: current | Show results with:current. 30, Mr. Imran Khan, 18-08-2018 To 10-04-2022, Slowing Dow ; 31, Mian Muhammad Shehbaz Sharif, 11-04-2022 To 14-08-2023, Slowing Dow. Prime Minister of Pakistan. Mian Muhammad Shehbaz Sharif. Prime Minister of the Islamic Republic of Pakistan and President of the Pakistan Muslim League (N). Prime Minister Muhammad Shahbaz Sharif took oath of the office on 4 March 2024. Previously, he served as the Prime Minister of Pakistan from April - 2022 to ... Missing: current | Show results with:current. Mian Muhammad Shehbaz Sharif is a Pakistani politician and businessman who is currently serving as the 24th prime minister of Pakistan since March 2024,  ...
#  StateSnapshot(values={'messages': [HumanMessage(content='what is the capital of Pakistan?', additional_kwargs={}, response_metadata={}, id='22cefe5a-3a8e-4e0c-8dec-ec0c5111d944'), AIMessage(content='The capital of Pakistan is Islamabad.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 95, 'total_tokens': 103, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a1681c17ec', 'id': 'chatcmpl-DJZmAJe7C1q8jQUixGNfNC1oEEetD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--ae978d0a-30f2-4c8a-9bfc-93e0d15a3d19-0', usage_metadata={'input_tokens': 95, 'output_tokens': 8, 'total_tokens': 103, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Who is the prime minister?', additional_kwargs={}, response_metadata={}, id='a4e2606e-8140-4023-bb74-835454ff8967')]}, next=('chatbot',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1203ce-71da-697c-8003-6b9f4639fbaa'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-03-15T07:02:17.280345+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1203ce-71d8-626f-8002-231c364497d3'}}, tasks=(PregelTask(id='889eaf73-ad4d-c95a-884f-06de2c7fdd5c', name='chatbot', path=('__pregel_pull', 'chatbot'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_0EAUp7sdGSZOMRtiyiZfyxwx', 'function': {'arguments': '{"__arg1":"current Prime Minister of Pakistan 2023"}', 'name': 'search'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 116, 'total_tokens': 138, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a1681c17ec', 'id': 'chatcmpl-DJZmNNsBI1qP9ctba2KLI60XYzdlj', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--91c2d56a-8787-496b-a127-48f80011a56a-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'current Prime Minister of Pakistan 2023'}, 'id': 'call_0EAUp7sdGSZOMRtiyiZfyxwx', 'type': 'tool_call'}], usage_metadata={'input_tokens': 116, 'output_tokens': 22, 'total_tokens': 138, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}),), interrupts=()),
#  StateSnapshot(values={'messages': [HumanMessage(content='what is the capital of Pakistan?', additional_kwargs={}, response_metadata={}, id='22cefe5a-3a8e-4e0c-8dec-ec0c5111d944'), AIMessage(content='The capital of Pakistan is Islamabad.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 95, 'total_tokens': 103, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a1681c17ec', 'id': 'chatcmpl-DJZmAJe7C1q8jQUixGNfNC1oEEetD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--ae978d0a-30f2-4c8a-9bfc-93e0d15a3d19-0', usage_metadata={'input_tokens': 95, 'output_tokens': 8, 'total_tokens': 103, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1203ce-71d8-626f-8002-231c364497d3'}}, metadata={'source': 'input', 'step': 2, 'parents': {}}, created_at='2026-03-15T07:02:17.279345+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1203ce-08b0-60e4-8001-8a49156ef7f0'}}, tasks=(PregelTask(id='8f24eb1a-57f8-af18-084e-12b606515e81', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'messages': [{'role': 'user', 'content': 'Who is the prime minister?'}]}),), interrupts=()),
#  StateSnapshot(values={'messages': [HumanMessage(content='what is the capital of Pakistan?', additional_kwargs={}, response_metadata={}, id='22cefe5a-3a8e-4e0c-8dec-ec0c5111d944'), AIMessage(content='The capital of Pakistan is Islamabad.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 95, 'total_tokens': 103, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a1681c17ec', 'id': 'chatcmpl-DJZmAJe7C1q8jQUixGNfNC1oEEetD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--ae978d0a-30f2-4c8a-9bfc-93e0d15a3d19-0', usage_metadata={'input_tokens': 95, 'output_tokens': 8, 'total_tokens': 103, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1203ce-08b0-60e4-8001-8a49156ef7f0'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-03-15T07:02:06.252874+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1203cd-f883-6c0f-8000-37c0835a8065'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'messages': [HumanMessage(content='what is the capital of Pakistan?', additional_kwargs={}, response_metadata={}, id='22cefe5a-3a8e-4e0c-8dec-ec0c5111d944')]}, next=('chatbot',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1203cd-f883-6c0f-8000-37c0835a8065'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-03-15T07:02:04.557006+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1203cd-f87e-6b3b-bfff-60dff37b5c10'}}, tasks=(PregelTask(id='2e77e146-8e36-8b4d-320d-fb56443a693f', name='chatbot', path=('__pregel_pull', 'chatbot'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content='The capital of Pakistan is Islamabad.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 95, 'total_tokens': 103, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a1681c17ec', 'id': 'chatcmpl-DJZmAJe7C1q8jQUixGNfNC1oEEetD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--ae978d0a-30f2-4c8a-9bfc-93e0d15a3d19-0', usage_metadata={'input_tokens': 95, 'output_tokens': 8, 'total_tokens': 103, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}),), interrupts=()),
#  StateSnapshot(values={'messages': []}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1203cd-f87e-6b3b-bfff-60dff37b5c10'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-03-15T07:02:04.554937+00:00', parent_config=None, tasks=(PregelTask(id='3f13e337-b12a-c0e8-6330-129db332b27a', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'messages': [{'role': 'user', 'content': 'what is the capital of Pakistan?'}]}),), interrupts=())]

# %% [markdown]
# ### LangGraph gives you tools to set the state back to a prior point in time, to branch off:
#
# ```
# config = {"configurable": {"thread_id": "1", "checkpoint_id": ...}}
# graph.invoke(None, config=config)
# ```
#
# And this allows you to build stable systems that can be recovered and rerun from any prior checkpoint.

# %% [markdown]
# ### And now let's store in SQL
#
# ### And this is the power of LangGraph.

# %%
import sqlite3
from langgraph.checkpoint.sqlite import SqliteSaver

db_path = "memory.db"
conn = sqlite3.connect(db_path, check_same_thread=False)
sql_memory = SqliteSaver(conn)

# %%
# Steps 1 and 2
graph_builder = StateGraph(State)


# Step 3
llm = ChatOpenAI(model="gpt-4o-mini")
llm_with_tools = llm.bind_tools(tools)

def chatbot(state: State):
    print(state)
    return {"messages": [llm_with_tools.invoke(state["messages"])]}

graph_builder.add_node("chatbot", chatbot)
graph_builder.add_node("tools", ToolNode(tools=tools))

# Step 4
graph_builder.add_conditional_edges( "chatbot", tools_condition, "tools")
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START, "chatbot")

# Step 5
graph = graph_builder.compile(checkpointer=sql_memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
config = {"configurable": {"thread_id": "3"}}

def chat(user_input: str, history):
    result = graph.invoke({"messages": [{"role": "user", "content": user_input}]}, config=config)
    return result["messages"][-1].content


gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7864
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# {'messages': [HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='d6144090-9963-438c-b21b-3fb4f06edbc0'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 90, 'total_tokens': 101, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInN7JUnEYNTQqokCF3eihp5oKP0V', 'finish_reason': 'stop', 'logprobs': None}, id='run-4b488710-73ac-435e-a944-913a0c812d08-0', usage_metadata={'input_tokens': 90, 'output_tokens': 11, 'total_tokens': 101, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="what's my name", additional_kwargs={}, response_metadata={}, id='0ee3236f-a0f8-487c-9e18-3a1a83e91d81'), AIMessage(content="I don't have access to personal information unless you provide it. What would you like me to call you?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 111, 'total_tokens': 134, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInNEm0T32rf7Lx23sOvrcePfgL8d', 'finish_reason': 'stop', 'logprobs': None}, id='run-c12bd46c-0c94-475c-b281-89773b1947a2-0', usage_metadata={'input_tokens': 111, 'output_tokens': 23, 'total_tokens': 134, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="My name's Ed", additional_kwargs={}, response_metadata={}, id='65e59191-b993-4faf-9699-197f70b79fcd'), AIMessage(content='Nice to meet you, Ed! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 144, 'total_tokens': 160, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInNLLW9Z5vrmr2MUfk6CLJBnCMOg', 'finish_reason': 'stop', 'logprobs': None}, id='run-68e08e4e-bc27-4802-b800-8fb359a5d976-0', usage_metadata={'input_tokens': 144, 'output_tokens': 16, 'total_tokens': 160, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='dfeeb914-53d6-404f-9a5c-0531f1fe43fe'), AIMessage(content='Hello again, Ed! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 168, 'total_tokens': 182, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInOS7TKECQA9Trbcv3mBsxkVJ8c3', 'finish_reason': 'stop', 'logprobs': None}, id='run-8b9e7d2c-d34d-4d84-99d2-dcb6b26b84bf-0', usage_metadata={'input_tokens': 168, 'output_tokens': 14, 'total_tokens': 182, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='please send me a push notification with the current usd/gbp exchange rate', additional_kwargs={}, response_metadata={}, id='6e096518-8d44 ...
# {'messages': [HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='d6144090-9963-438c-b21b-3fb4f06edbc0'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 90, 'total_tokens': 101, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInN7JUnEYNTQqokCF3eihp5oKP0V', 'finish_reason': 'stop', 'logprobs': None}, id='run-4b488710-73ac-435e-a944-913a0c812d08-0', usage_metadata={'input_tokens': 90, 'output_tokens': 11, 'total_tokens': 101, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="what's my name", additional_kwargs={}, response_metadata={}, id='0ee3236f-a0f8-487c-9e18-3a1a83e91d81'), AIMessage(content="I don't have access to personal information unless you provide it. What would you like me to call you?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 111, 'total_tokens': 134, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInNEm0T32rf7Lx23sOvrcePfgL8d', 'finish_reason': 'stop', 'logprobs': None}, id='run-c12bd46c-0c94-475c-b281-89773b1947a2-0', usage_metadata={'input_tokens': 111, 'output_tokens': 23, 'total_tokens': 134, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="My name's Ed", additional_kwargs={}, response_metadata={}, id='65e59191-b993-4faf-9699-197f70b79fcd'), AIMessage(content='Nice to meet you, Ed! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 144, 'total_tokens': 160, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInNLLW9Z5vrmr2MUfk6CLJBnCMOg', 'finish_reason': 'stop', 'logprobs': None}, id='run-68e08e4e-bc27-4802-b800-8fb359a5d976-0', usage_metadata={'input_tokens': 144, 'output_tokens': 16, 'total_tokens': 160, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='dfeeb914-53d6-404f-9a5c-0531f1fe43fe'), AIMessage(content='Hello again, Ed! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 168, 'total_tokens': 182, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInOS7TKECQA9Trbcv3mBsxkVJ8c3', 'finish_reason': 'stop', 'logprobs': None}, id='run-8b9e7d2c-d34d-4d84-99d2-dcb6b26b84bf-0', usage_metadata={'input_tokens': 168, 'output_tokens': 14, 'total_tokens': 182, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='please send me a push notification with the current usd/gbp exchange rate', additional_kwargs={}, response_metadata={}, id='6e096518-8d44 ...
# {'messages': [HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='d6144090-9963-438c-b21b-3fb4f06edbc0'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 90, 'total_tokens': 101, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInN7JUnEYNTQqokCF3eihp5oKP0V', 'finish_reason': 'stop', 'logprobs': None}, id='run-4b488710-73ac-435e-a944-913a0c812d08-0', usage_metadata={'input_tokens': 90, 'output_tokens': 11, 'total_tokens': 101, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="what's my name", additional_kwargs={}, response_metadata={}, id='0ee3236f-a0f8-487c-9e18-3a1a83e91d81'), AIMessage(content="I don't have access to personal information unless you provide it. What would you like me to call you?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 111, 'total_tokens': 134, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInNEm0T32rf7Lx23sOvrcePfgL8d', 'finish_reason': 'stop', 'logprobs': None}, id='run-c12bd46c-0c94-475c-b281-89773b1947a2-0', usage_metadata={'input_tokens': 111, 'output_tokens': 23, 'total_tokens': 134, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="My name's Ed", additional_kwargs={}, response_metadata={}, id='65e59191-b993-4faf-9699-197f70b79fcd'), AIMessage(content='Nice to meet you, Ed! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 144, 'total_tokens': 160, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInNLLW9Z5vrmr2MUfk6CLJBnCMOg', 'finish_reason': 'stop', 'logprobs': None}, id='run-68e08e4e-bc27-4802-b800-8fb359a5d976-0', usage_metadata={'input_tokens': 144, 'output_tokens': 16, 'total_tokens': 160, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='dfeeb914-53d6-404f-9a5c-0531f1fe43fe'), AIMessage(content='Hello again, Ed! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 168, 'total_tokens': 182, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInOS7TKECQA9Trbcv3mBsxkVJ8c3', 'finish_reason': 'stop', 'logprobs': None}, id='run-8b9e7d2c-d34d-4d84-99d2-dcb6b26b84bf-0', usage_metadata={'input_tokens': 168, 'output_tokens': 14, 'total_tokens': 182, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='please send me a push notification with the current usd/gbp exchange rate', additional_kwargs={}, response_metadata={}, id='6e096518-8d44 ...
# {'messages': [HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='d6144090-9963-438c-b21b-3fb4f06edbc0'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 90, 'total_tokens': 101, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInN7JUnEYNTQqokCF3eihp5oKP0V', 'finish_reason': 'stop', 'logprobs': None}, id='run-4b488710-73ac-435e-a944-913a0c812d08-0', usage_metadata={'input_tokens': 90, 'output_tokens': 11, 'total_tokens': 101, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="what's my name", additional_kwargs={}, response_metadata={}, id='0ee3236f-a0f8-487c-9e18-3a1a83e91d81'), AIMessage(content="I don't have access to personal information unless you provide it. What would you like me to call you?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 111, 'total_tokens': 134, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInNEm0T32rf7Lx23sOvrcePfgL8d', 'finish_reason': 'stop', 'logprobs': None}, id='run-c12bd46c-0c94-475c-b281-89773b1947a2-0', usage_metadata={'input_tokens': 111, 'output_tokens': 23, 'total_tokens': 134, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="My name's Ed", additional_kwargs={}, response_metadata={}, id='65e59191-b993-4faf-9699-197f70b79fcd'), AIMessage(content='Nice to meet you, Ed! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 144, 'total_tokens': 160, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInNLLW9Z5vrmr2MUfk6CLJBnCMOg', 'finish_reason': 'stop', 'logprobs': None}, id='run-68e08e4e-bc27-4802-b800-8fb359a5d976-0', usage_metadata={'input_tokens': 144, 'output_tokens': 16, 'total_tokens': 160, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='dfeeb914-53d6-404f-9a5c-0531f1fe43fe'), AIMessage(content='Hello again, Ed! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 168, 'total_tokens': 182, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInOS7TKECQA9Trbcv3mBsxkVJ8c3', 'finish_reason': 'stop', 'logprobs': None}, id='run-8b9e7d2c-d34d-4d84-99d2-dcb6b26b84bf-0', usage_metadata={'input_tokens': 168, 'output_tokens': 14, 'total_tokens': 182, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='please send me a push notification with the current usd/gbp exchange rate', additional_kwargs={}, response_metadata={}, id='6e096518-8d44 ...
# {'messages': [HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='d6144090-9963-438c-b21b-3fb4f06edbc0'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 90, 'total_tokens': 101, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInN7JUnEYNTQqokCF3eihp5oKP0V', 'finish_reason': 'stop', 'logprobs': None}, id='run-4b488710-73ac-435e-a944-913a0c812d08-0', usage_metadata={'input_tokens': 90, 'output_tokens': 11, 'total_tokens': 101, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="what's my name", additional_kwargs={}, response_metadata={}, id='0ee3236f-a0f8-487c-9e18-3a1a83e91d81'), AIMessage(content="I don't have access to personal information unless you provide it. What would you like me to call you?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 111, 'total_tokens': 134, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInNEm0T32rf7Lx23sOvrcePfgL8d', 'finish_reason': 'stop', 'logprobs': None}, id='run-c12bd46c-0c94-475c-b281-89773b1947a2-0', usage_metadata={'input_tokens': 111, 'output_tokens': 23, 'total_tokens': 134, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="My name's Ed", additional_kwargs={}, response_metadata={}, id='65e59191-b993-4faf-9699-197f70b79fcd'), AIMessage(content='Nice to meet you, Ed! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 144, 'total_tokens': 160, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInNLLW9Z5vrmr2MUfk6CLJBnCMOg', 'finish_reason': 'stop', 'logprobs': None}, id='run-68e08e4e-bc27-4802-b800-8fb359a5d976-0', usage_metadata={'input_tokens': 144, 'output_tokens': 16, 'total_tokens': 160, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='dfeeb914-53d6-404f-9a5c-0531f1fe43fe'), AIMessage(content='Hello again, Ed! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 168, 'total_tokens': 182, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInOS7TKECQA9Trbcv3mBsxkVJ8c3', 'finish_reason': 'stop', 'logprobs': None}, id='run-8b9e7d2c-d34d-4d84-99d2-dcb6b26b84bf-0', usage_metadata={'input_tokens': 168, 'output_tokens': 14, 'total_tokens': 182, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='please send me a push notification with the current usd/gbp exchange rate', additional_kwargs={}, response_metadata={}, id='6e096518-8d44 ...
# {'messages': [HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='d6144090-9963-438c-b21b-3fb4f06edbc0'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 90, 'total_tokens': 101, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInN7JUnEYNTQqokCF3eihp5oKP0V', 'finish_reason': 'stop', 'logprobs': None}, id='run-4b488710-73ac-435e-a944-913a0c812d08-0', usage_metadata={'input_tokens': 90, 'output_tokens': 11, 'total_tokens': 101, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="what's my name", additional_kwargs={}, response_metadata={}, id='0ee3236f-a0f8-487c-9e18-3a1a83e91d81'), AIMessage(content="I don't have access to personal information unless you provide it. What would you like me to call you?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 111, 'total_tokens': 134, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInNEm0T32rf7Lx23sOvrcePfgL8d', 'finish_reason': 'stop', 'logprobs': None}, id='run-c12bd46c-0c94-475c-b281-89773b1947a2-0', usage_metadata={'input_tokens': 111, 'output_tokens': 23, 'total_tokens': 134, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="My name's Ed", additional_kwargs={}, response_metadata={}, id='65e59191-b993-4faf-9699-197f70b79fcd'), AIMessage(content='Nice to meet you, Ed! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 144, 'total_tokens': 160, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInNLLW9Z5vrmr2MUfk6CLJBnCMOg', 'finish_reason': 'stop', 'logprobs': None}, id='run-68e08e4e-bc27-4802-b800-8fb359a5d976-0', usage_metadata={'input_tokens': 144, 'output_tokens': 16, 'total_tokens': 160, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='dfeeb914-53d6-404f-9a5c-0531f1fe43fe'), AIMessage(content='Hello again, Ed! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 168, 'total_tokens': 182, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInOS7TKECQA9Trbcv3mBsxkVJ8c3', 'finish_reason': 'stop', 'logprobs': None}, id='run-8b9e7d2c-d34d-4d84-99d2-dcb6b26b84bf-0', usage_metadata={'input_tokens': 168, 'output_tokens': 14, 'total_tokens': 182, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='please send me a push notification with the current usd/gbp exchange rate', additional_kwargs={}, response_metadata={}, id='6e096518-8d44 ...
# {'messages': [HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='d6144090-9963-438c-b21b-3fb4f06edbc0'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 90, 'total_tokens': 101, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInN7JUnEYNTQqokCF3eihp5oKP0V', 'finish_reason': 'stop', 'logprobs': None}, id='run-4b488710-73ac-435e-a944-913a0c812d08-0', usage_metadata={'input_tokens': 90, 'output_tokens': 11, 'total_tokens': 101, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="what's my name", additional_kwargs={}, response_metadata={}, id='0ee3236f-a0f8-487c-9e18-3a1a83e91d81'), AIMessage(content="I don't have access to personal information unless you provide it. What would you like me to call you?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 111, 'total_tokens': 134, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInNEm0T32rf7Lx23sOvrcePfgL8d', 'finish_reason': 'stop', 'logprobs': None}, id='run-c12bd46c-0c94-475c-b281-89773b1947a2-0', usage_metadata={'input_tokens': 111, 'output_tokens': 23, 'total_tokens': 134, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="My name's Ed", additional_kwargs={}, response_metadata={}, id='65e59191-b993-4faf-9699-197f70b79fcd'), AIMessage(content='Nice to meet you, Ed! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 144, 'total_tokens': 160, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInNLLW9Z5vrmr2MUfk6CLJBnCMOg', 'finish_reason': 'stop', 'logprobs': None}, id='run-68e08e4e-bc27-4802-b800-8fb359a5d976-0', usage_metadata={'input_tokens': 144, 'output_tokens': 16, 'total_tokens': 160, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='dfeeb914-53d6-404f-9a5c-0531f1fe43fe'), AIMessage(content='Hello again, Ed! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 168, 'total_tokens': 182, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInOS7TKECQA9Trbcv3mBsxkVJ8c3', 'finish_reason': 'stop', 'logprobs': None}, id='run-8b9e7d2c-d34d-4d84-99d2-dcb6b26b84bf-0', usage_metadata={'input_tokens': 168, 'output_tokens': 14, 'total_tokens': 182, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='please send me a push notification with the current usd/gbp exchange rate', additional_kwargs={}, response_metadata={}, id='6e096518-8d44 ...
# {'messages': [HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='d6144090-9963-438c-b21b-3fb4f06edbc0'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 90, 'total_tokens': 101, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInN7JUnEYNTQqokCF3eihp5oKP0V', 'finish_reason': 'stop', 'logprobs': None}, id='run-4b488710-73ac-435e-a944-913a0c812d08-0', usage_metadata={'input_tokens': 90, 'output_tokens': 11, 'total_tokens': 101, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="what's my name", additional_kwargs={}, response_metadata={}, id='0ee3236f-a0f8-487c-9e18-3a1a83e91d81'), AIMessage(content="I don't have access to personal information unless you provide it. What would you like me to call you?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 111, 'total_tokens': 134, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInNEm0T32rf7Lx23sOvrcePfgL8d', 'finish_reason': 'stop', 'logprobs': None}, id='run-c12bd46c-0c94-475c-b281-89773b1947a2-0', usage_metadata={'input_tokens': 111, 'output_tokens': 23, 'total_tokens': 134, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="My name's Ed", additional_kwargs={}, response_metadata={}, id='65e59191-b993-4faf-9699-197f70b79fcd'), AIMessage(content='Nice to meet you, Ed! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 144, 'total_tokens': 160, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInNLLW9Z5vrmr2MUfk6CLJBnCMOg', 'finish_reason': 'stop', 'logprobs': None}, id='run-68e08e4e-bc27-4802-b800-8fb359a5d976-0', usage_metadata={'input_tokens': 144, 'output_tokens': 16, 'total_tokens': 160, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='dfeeb914-53d6-404f-9a5c-0531f1fe43fe'), AIMessage(content='Hello again, Ed! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 168, 'total_tokens': 182, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInOS7TKECQA9Trbcv3mBsxkVJ8c3', 'finish_reason': 'stop', 'logprobs': None}, id='run-8b9e7d2c-d34d-4d84-99d2-dcb6b26b84bf-0', usage_metadata={'input_tokens': 168, 'output_tokens': 14, 'total_tokens': 182, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='please send me a push notification with the current usd/gbp exchange rate', additional_kwargs={}, response_metadata={}, id='6e096518-8d44 ...
# {'messages': [HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='d6144090-9963-438c-b21b-3fb4f06edbc0'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 90, 'total_tokens': 101, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInN7JUnEYNTQqokCF3eihp5oKP0V', 'finish_reason': 'stop', 'logprobs': None}, id='run-4b488710-73ac-435e-a944-913a0c812d08-0', usage_metadata={'input_tokens': 90, 'output_tokens': 11, 'total_tokens': 101, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="what's my name", additional_kwargs={}, response_metadata={}, id='0ee3236f-a0f8-487c-9e18-3a1a83e91d81'), AIMessage(content="I don't have access to personal information unless you provide it. What would you like me to call you?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 111, 'total_tokens': 134, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInNEm0T32rf7Lx23sOvrcePfgL8d', 'finish_reason': 'stop', 'logprobs': None}, id='run-c12bd46c-0c94-475c-b281-89773b1947a2-0', usage_metadata={'input_tokens': 111, 'output_tokens': 23, 'total_tokens': 134, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="My name's Ed", additional_kwargs={}, response_metadata={}, id='65e59191-b993-4faf-9699-197f70b79fcd'), AIMessage(content='Nice to meet you, Ed! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 144, 'total_tokens': 160, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInNLLW9Z5vrmr2MUfk6CLJBnCMOg', 'finish_reason': 'stop', 'logprobs': None}, id='run-68e08e4e-bc27-4802-b800-8fb359a5d976-0', usage_metadata={'input_tokens': 144, 'output_tokens': 16, 'total_tokens': 160, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='dfeeb914-53d6-404f-9a5c-0531f1fe43fe'), AIMessage(content='Hello again, Ed! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 168, 'total_tokens': 182, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInOS7TKECQA9Trbcv3mBsxkVJ8c3', 'finish_reason': 'stop', 'logprobs': None}, id='run-8b9e7d2c-d34d-4d84-99d2-dcb6b26b84bf-0', usage_metadata={'input_tokens': 168, 'output_tokens': 14, 'total_tokens': 182, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='please send me a push notification with the current usd/gbp exchange rate', additional_kwargs={}, response_metadata={}, id='6e096518-8d44 ...
# {'messages': [HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='d6144090-9963-438c-b21b-3fb4f06edbc0'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 90, 'total_tokens': 101, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInN7JUnEYNTQqokCF3eihp5oKP0V', 'finish_reason': 'stop', 'logprobs': None}, id='run-4b488710-73ac-435e-a944-913a0c812d08-0', usage_metadata={'input_tokens': 90, 'output_tokens': 11, 'total_tokens': 101, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="what's my name", additional_kwargs={}, response_metadata={}, id='0ee3236f-a0f8-487c-9e18-3a1a83e91d81'), AIMessage(content="I don't have access to personal information unless you provide it. What would you like me to call you?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 111, 'total_tokens': 134, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInNEm0T32rf7Lx23sOvrcePfgL8d', 'finish_reason': 'stop', 'logprobs': None}, id='run-c12bd46c-0c94-475c-b281-89773b1947a2-0', usage_metadata={'input_tokens': 111, 'output_tokens': 23, 'total_tokens': 134, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="My name's Ed", additional_kwargs={}, response_metadata={}, id='65e59191-b993-4faf-9699-197f70b79fcd'), AIMessage(content='Nice to meet you, Ed! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 144, 'total_tokens': 160, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInNLLW9Z5vrmr2MUfk6CLJBnCMOg', 'finish_reason': 'stop', 'logprobs': None}, id='run-68e08e4e-bc27-4802-b800-8fb359a5d976-0', usage_metadata={'input_tokens': 144, 'output_tokens': 16, 'total_tokens': 160, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='dfeeb914-53d6-404f-9a5c-0531f1fe43fe'), AIMessage(content='Hello again, Ed! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 168, 'total_tokens': 182, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BInOS7TKECQA9Trbcv3mBsxkVJ8c3', 'finish_reason': 'stop', 'logprobs': None}, id='run-8b9e7d2c-d34d-4d84-99d2-dcb6b26b84bf-0', usage_metadata={'input_tokens': 168, 'output_tokens': 14, 'total_tokens': 182, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='please send me a push notification with the current usd/gbp exchange rate', additional_kwargs={}, response_metadata={}, id='6e096518-8d44 ...
